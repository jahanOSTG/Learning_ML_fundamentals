# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose # Corrected 'sessional' to 'seasonal'
import numpy as np
import pandas as pd

# %%
x=[1,2,3,4,10]
y=[5,4,3,2,1]

# %%
fig = plt.figure(figsize=(10,6))

gs = gridspec.GridSpec(2, 3)

ax1 = fig.add_subplot(gs[0,0])
ax1.plot(x,y, 'r-*')
ax1.set_title("Top Left")


ax2 = fig.add_subplot(gs[1,0])
ax2.plot(x,y, 'g-*')
ax2.set_title("Bottom Left")

ax3 = fig.add_subplot(gs[0,1])
ax3.plot(x,y, 'm-o')
ax3.set_title("Top Middle")

ax4 = fig.add_subplot(gs[1,1])
ax4.plot(x,y, 'c-o')
ax4.set_title("Bottom Middle")

ax5 = fig.add_subplot(gs[:,2])
ax5.plot(x,y, 'b-*')
ax5.set_title("Full right")

plt.tight_layout()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Time Series data.csv')
df.head()
# Out:
#    Avg_Temperature  Ice_Cream_Sales  Power_Cuts
# 0        25.661274       591.163282         5.0
# 1        26.560024       657.393558         3.0
# 2        28.596623       779.978584         4.0
# 3        28.104512       726.827852         5.0
# 4        29.889647       775.217459         5.0

# %%
df.shape
# Out:
# (120, 3)

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data=df[['Avg_Temperature', 'Ice_Cream_Sales', 'Power_Cuts']])
plt.title("Temperature, Ice cream Sales and Power cuts over time")
plt.xlabel("Month")
plt.ylabel("Values")
plt.legend(["Temperature degree celcisus", "Ice cream sales", "Power cuts"])
plt.tight_layout()
plt.show()

# %%
df['Temp_MA_6'] = df['Avg_Temperature'].rolling(window=6).mean()
df['IceCream_Sales_MA_6'] = df['Ice_Cream_Sales'].rolling(window=6).mean()

# %%
df.head(10)
# Out:
#    Avg_Temperature  Ice_Cream_Sales  Power_Cuts  Temp_MA_6  \
# 0        25.661274       591.163282         5.0        NaN
# 1        26.560024       657.393558         3.0        NaN
# 2        28.596623       779.978584         4.0        NaN
# 3        28.104512       726.827852         5.0        NaN
# 4        29.889647       775.217459         5.0        NaN
# 5        18.074189       220.867731         0.0  26.147711
# 6        13.913798       -16.165218         0.0  24.189799
# 7        12.661206       -45.941386         0.0  21.873329
# 8         9.110366      -251.292061         0.0  18.625619
# 9        10.641652      -170.066611         0.0  15.715143
#
#    IceCream_Sales_MA_6
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5           625.241411
# 6           524.019994
# 7           406.797504
# 8           234.919063
# 9            85.436652

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data=df[['Avg_Temperature', 'Temp_MA_6', 'Ice_Cream_Sales', 'IceCream_Sales_MA_6']])
plt.title("Temperature, Ice cream Sales and Power cuts over time")
plt.xlabel("Month")
plt.ylabel("Values")
plt.legend(["Temperature degree celcisus", "6 month MA", "Ice cream sales", "6 month MA"])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data=df[['Avg_Temperature', 'Temp_MA_6']])
plt.title("Temperature with 6 month moving average")
plt.xlabel("Month")
plt.ylabel("Temperature")
plt.legend(["Temperature", "6-month MA"])
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Sessional decomposition has 2 models:**
#  ### additive-if data = trend + seasonality + noise
# ### multiplicative-if data = trend * seasonality * noise

# %%
plt.figure(figsize=(12,5))
plt.fill_between(df.index, df['Ice_Cream_Sales'], alpha=0.4, label="Ice Cream Sales", color="orange")
plt.fill_between(df.index, df['Power_Cuts'], alpha=0.9, label="Power cuts", color="red")
plt.title("Area chart: Ice cream sales vs power cuts")
plt.xlabel("Month")
plt.ylabel("Counts")
plt.legend()
plt.tight_layout()
plt.show()

# %%
result = seasonal_decompose(df['Avg_Temperature'], model='additive', period=12)
result.plot()
plt.suptitle("Seasonal Decomposition of temperature", fontsize=16)
plt.tight_layout()
plt.show()
